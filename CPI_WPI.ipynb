# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sn
import plotly.express as px

# %%
df = pd.read_csv("WPI_table_1_edited.csv")
df.head()
# Out:
#        dates  \
# 0  1/09/1997
# 1  1/12/1997
# 2  1/03/1998
# 3  1/06/1998
# 4  1/09/1998
#
#    Quarterly Total hourly rates of pay excluding bonuses Australia Private All industries   \
# 0                                               67.4
# 1                                               67.9
# 2                                               68.5
# 3                                               68.8
# 4                                               69.6
#
#    Quarterly Total hourly rates of pay excluding bonuses Australia Public All industries   \
# 0                                               64.7
# 1                                               65.2
# 2                                               65.9
# 3                                               66.2
# 4                                               67.2
#
#    Quarterly Total hourly rates of pay excluding bonuses Australia Private and Public All industries   \
# 0                                               66.7
# 1                                               67.3
# 2                                               67.8
# 3                                               68.2
# 4                                               68.9
#
#    Total hourly rates of pay Private  Total hourly rates of pay Public   \
# 0                               67.3                               64.8
# 1                               67.9                               65.3
# 2                               68.5                               65.8
# 3                               69.0                               66.3
# 4                               69.4                               67.1
#
#    Total hourly rates of payPrivate and Public  \
# 0                                         66.6
# 1                                         67.2
# 2                                         67.8
# 3                                         68.3
# 4                                         68.8
#
#    Quarterly Total hourly rates of pay excluding bonuses Australia Private All industries 2  \
# 0                                               67.3
# 1                                               67.9
# 2                                               68.5
# 3                                               69.0
# 4                                               69.4
#
#    Quarterly Total hourly rates of pay excluding bonuses Australia Public All industries 2  \
# 0                                               64.8
# 1                                               65.3
# 2                                               65.8
# 3                                               66.4
# 4                                               67.0
#
#    Quarterly Total hourly rates of pay excluding bonuses Australia Private and Public All industries 2  \
# 0                                               66.7
# 1                                               67.2
# 2                                               67.8
# 3                                               68.3
# 4                                               68.8
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Percentage Change From Previous Quarter Australia Total hourly rates of pay excluding bonuses Private and Public All industries 2  \
# 0                                                NaN
# 1                                                0.7
# 2                                                0.9
# 3                                                0.7
# 4                                                0.7
#
#    Percentage Change from Corresponding Quarter of Previous Year Total hourly rates of pay excluding bonuses Australia Private All industries   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.3
#
#    Percentage Change from Corresponding Quarter of Previous Year Total hourly rates of pay excluding bonuses Australia Public All industries   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.9
#
#    Percentage Change from Corresponding Quarter of Previous Year Total hourly rates of pay excluding bonuses Australia Private and Public All industries   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.3
#
#    Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private All industries 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.1
#
#    Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Public All industries 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.5
#
#    Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private and Public All industries 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.3
#
#    Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private All industries 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.1
#
#    Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Public All industries 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.4
#
#    Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private and Public All industries 2
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                3.1
#
# [5 rows x 28 columns]

# %%
df['dates'].unique()
# Out:
# array(['1/09/1997', '1/12/1997', '1/03/1998', '1/06/1998', '1/09/1998',
#        '1/12/1998', '1/03/1999', '1/06/1999', '1/09/1999', '1/12/1999',
#        '1/03/2000', '1/06/2000', '1/09/2000', '1/12/2000', '1/03/2001',
#        '1/06/2001', '1/09/2001', '1/12/2001', '1/03/2002', '1/06/2002',
#        '1/09/2002', '1/12/2002', '1/03/2003', '1/06/2003', '1/09/2003',
#        '1/12/2003', '1/03/2004', '1/06/2004', '1/09/2004', '1/12/2004',
#        '1/03/2005', '1/06/2005', '1/09/2005', '1/12/2005', '1/03/2006',
#        '1/06/2006', '1/09/2006', '1/12/2006', '1/03/2007', '1/06/2007',
#        '1/09/2007', '1/12/2007', '1/03/2008', '1/06/2008', '1/09/2008',
#        '1/12/2008', '1/03/2009', '1/06/2009', '1/09/2009', '1/12/2009',
#        '1/03/2010', '1/06/2010', '1/09/2010', '1/12/2010', '1/03/2011',
#        '1/06/2011', '1/09/2011', '1/12/2011', '1/03/2012', '1/06/2012',
#        '1/09/2012', '1/12/2012', '1/03/2013', '1/06/2013', '1/09/2013',
#        '1/12/2013', '1/03/2014', '1/06/2014', '1/09/2014', '1/12/2014',
#        '1/03/2015', '1/06/2015', '1/09/2015', '1/12/2015', '1/03/2016',
#        '1/06/2016', '1/09/2016', '1/12/2016', '1/03/2017', '1/06/2017',
#        '1/09/2017', '1/12/2017', '1/03/2018', '1/06/2018', '1/09/2018',
#        '1/12/2018', '1/03/2019', '1/06/2019', '1/09/2019', '1/12/2019',
#        '1/03/2020', '1/06/2020', '1/09/2020', '1/12/2020', '1/03/2021',
#        '1/06/2021', '1/09/2021', '1/12/2021', '1/03/2022', '1/06/2022',
#        '1/09/2022', '1/12/2022', '1/03/2023'], dtype=object)

# %%
df.shape
# Out:
# (103, 28)

# %%
df.isna().sum()
# Out:
# dates                                                                                                                                                      0
# Quarterly Total hourly rates of pay excluding bonuses Australia Private All industries                                                                     0
# Quarterly Total hourly rates of pay excluding bonuses Australia Public All industries                                                                      0
# Quarterly Total hourly rates of pay excluding bonuses Australia Private and Public All industries                                                          0
# Total hourly rates of pay Private                                                                                                                          0
# Total hourly rates of pay Public                                                                                                                           0
# Total hourly rates of payPrivate and Public                                                                                                                0
# Quarterly Total hourly rates of pay excluding bonuses Australia Private All industries 2                                                                   0
# Quarterly Total hourly rates of pay excluding bonuses Australia Public All industries 2                                                                    0
# Quarterly Total hourly rates of pay excluding bonuses Australia Private and Public All industries 2                                                        0
# Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private All industries                                       1
# Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Public All industries                                        1
# Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private and Public All industries                            1
# Percentage Change From Previous Quarter Australia Total hourly rates of pay excluding bonuses Private All industries 1                                     1
# Percentage Change From Previous Quarter Australia Total hourly rates of pay excluding bonuses Public All industries 1                                      1
# Percentage Change From Previous Quarter Australia Total hourly rates of pay excluding bonuses Private and Public All industries 1                          1
# Percentage Change From Previous Quarter Australia Total hourly rates of pay excluding bonuses Private All industries 2                                     1
# Percentage Change From Previous Quarter Australia Total hourly rates of pay excluding bonuses Public All industries 2                                      1
# Percentage Change From Previous Quarter Australia Total hourly rates of pay excluding bonuses Private and Public All industries 2                          1
# Percentage Change from Corresponding Quarter of Previous Year Total hourly rates of pay excluding bonuses Australia Private All industries                 4
# Percentage Change from Corresponding Quarter of Previous Year Total hourly rates of pay excluding bonuses Australia Public All industries                  4
# Percentage Change from Corresponding Quarter of Previous Year Total hourly rates of pay excluding bonuses Australia Private and Public All industries      4
# Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private All industries 1               4
# Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Public All industries 1                4
# Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private and Public All industries 1    4
# Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private All industries 2               4
# Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Public All industries 2                4
# Percentage Change From Corresponding Quarter of Previous Year Australia Total hourly rates of pay excluding bonuses Private and Public All industries 2    4
# dtype: int64

# %%
df_WPI = df[["dates", "Total hourly rates of pay Private", "Total hourly rates of pay Public ", "Total hourly rates of payPrivate and Public"]]
df_WPI.head(10)
# Out:
#        dates  Total hourly rates of pay Private  \
# 0  1/09/1997                               67.3
# 1  1/12/1997                               67.9
# 2  1/03/1998                               68.5
# 3  1/06/1998                               69.0
# 4  1/09/1998                               69.4
# 5  1/12/1998                               69.9
# 6  1/03/1999                               70.4
# 7  1/06/1999                               71.0
# 8  1/09/1999                               71.4
# 9  1/12/1999                               71.9
#
#    Total hourly rates of pay Public   \
# 0                               64.8
# 1                               65.3
# 2                               65.8
# 3                               66.3
# 4                               67.1
# 5                               67.6
# 6                               68.5
# 7                               68.9
# 8                               69.4
# 9                               69.9
#
#    Total hourly rates of payPrivate and Public
# 0                                         66.6
# 1                                         67.2
# 2                                         67.8
# 3                                         68.3
# 4                                         68.8
# 5                                         69.3
# 6                                         69.9
# 7                                         70.4
# 8                                         70.9
# 9                                         71.4

# %%
# Private analysis vs public analysis

# %%
# Does Private or Public have more more of a price pay rise
#x = df_WPI["dates"]
#y = df_WPI["Total hourly rates of pay Private"]
#plt.plot(x, y, color = 'r')
#x = df_WPI["dates"]
#y = df_WPI["Total hourly rates of pay Public"]
#plt.plot(x, y, color = 'g')
#plt.show()

# %%
# Percentage change df per quarter 
percent_df = df[["dates", "Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private All industries", "Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Public All industries ", "Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private and Public All industries "]]
percent_df.head()
# Out:
#        dates  \
# 0  1/09/1997
# 1  1/12/1997
# 2  1/03/1998
# 3  1/06/1998
# 4  1/09/1998
#
#    Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private All industries  \
# 0                                                NaN
# 1                                                0.7
# 2                                                0.9
# 3                                                0.4
# 4                                                1.2
#
#    Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Public All industries   \
# 0                                                NaN
# 1                                                0.8
# 2                                                1.1
# 3                                                0.5
# 4                                                1.5
#
#    Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private and Public All industries
# 0                                                NaN
# 1                                                0.9
# 2                                                0.7
# 3                                                0.6
# 4                                                1.0

# %%
# Top 10 greatest percentage in Private
private_percentage_df = percent_df.sort_values(by='Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private All industries', ascending=False)

# %%
private_top_10_dates = private_percentage_df.head(10)

# %%
# Create a bar graph
plt.bar(private_top_10_dates['dates'], private_top_10_dates['Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private All industries'])
plt.xlabel('Date')
plt.ylabel('percentage increase')
plt.title('Top 10 greatest percentage increases Private')
plt.xticks(rotation=45)
plt.show()

# %%
# Top 10 greatest percentage in Public
public_percentage_df = percent_df.sort_values(by='Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Public All industries ', ascending=False)

# %%
public_top_10_dates = public_percentage_df.head(10)

# %%
# Create a bar graph
plt.bar(private_top_10_dates['dates'], private_top_10_dates['Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Public All industries '])
plt.xlabel('Date')
plt.ylabel('percentage increase')
plt.title('Top 10 greatest percentage increases Public')
plt.xticks(rotation=45)
plt.show()

# %%
all_percent_df = percent_df.sort_values(by='Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private and Public All industries ', ascending=False)

# %%
all_top_10_dates = all_percent_df.head(10)

# %%
# Top 10 greatest percentage in Australia
plt.bar(all_top_10_dates['dates'], all_top_10_dates['Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private and Public All industries '])
plt.xlabel('Date')
plt.ylabel('percentage increase')
plt.title('Top 10 greatest percentage increases Public')
plt.xticks(rotation=45)
plt.show()

# %%
# accumulated percentage Private
Private_percent_increase = percent_df['Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private All industries'].sum()
print(f"From 1/12/1997 There is an accumulated percentage increase in wages in the Private sector by: {Private_percent_increase}%" )
Private_price_increase = df['Total hourly rates of pay Private'].max() - df['Total hourly rates of pay Private'].min()
min = df['Total hourly rates of pay Private'].min()
max = df['Total hourly rates of pay Private'].max()
print(f"The difference in Private wage price increase is ${Private_price_increase}")
print(f"The min is ${min}")
print(f"The max is ${max}")
# Out:
# From 1/12/1997 There is an accumulated percentage increase in wages in the Private sector by: 75.9%
# The difference in Private wage price increase is $76.39999999999999
# The min is $67.3
# The max is $143.7

# %%
# accumulated percent public
Public_percent_increase = percent_df['Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Public All industries '].sum()
print(f"From 1/12/1997 There is an accumulated percentage increase in wages in the Public sector by: {Public_percent_increase}%" )
Public_price_increase = df['Total hourly rates of pay Public '].max() - df['Total hourly rates of pay Public '].min()
min = df['Total hourly rates of pay Public '].min()
max = df['Total hourly rates of pay Public '].max()
print(f"The difference in Public wage price increase is ${Public_price_increase}")
print(f"The min is ${min}")
print(f"The max is ${max}")
# Out:
# From 1/12/1997 There is an accumulated percentage increase in wages in the Public sector by: 81.9%
# The difference in Public wage price increase is $81.7
# The min is $64.8
# The max is $146.5

# %%
# accumulated percent total in Australia
all_percent_increase = percent_df['Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private and Public All industries '].sum()
print(f"From 1/12/1997 There is an accumulated percentage increase in wages in the Private and Public sector by: {all_percent_increase}%" )
Public_Prv_price_increase = df['Total hourly rates of payPrivate and Public'].max() - df['Total hourly rates of payPrivate and Public'].min()
min = df['Total hourly rates of payPrivate and Public'].min()
max = df['Total hourly rates of payPrivate and Public'].max()
print(f"The difference in Public and Private wage price increase is ${Public_Prv_price_increase}")
print(f"The min is ${min}")
print(f"The max is ${max}")
# Out:
# From 1/12/1997 There is an accumulated percentage increase in wages in the Private and Public sector by: 77.6%
# The difference in Public and Private wage price increase is $77.70000000000002
# The min is $66.6
# The max is $144.3

# %%
# line graph 
# plot line chart
plt.figure(figsize=(22,15))
plt.plot(percent_df["dates"], percent_df["Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private All industries"])
plt.plot(percent_df['dates'], percent_df['Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Public All industries '])
plt.title("Percentage increase in wages over time")
plt.xlabel('Quarters')
plt.ylabel('Salary_Hike')
plt.xticks(rotation=45)
plt.style.use('seaborn-white')

# %%
df1 = pd.read_csv("CPI_table_1_edited.csv")
df1.head()
# Out:
#        dates  Index Numbers ;  All groups CPI ;  Sydney ;  \
# 0  1/09/1948                                          3.7
# 1  1/12/1948                                          3.7
# 2  1/03/1949                                          3.9
# 3  1/06/1949                                          3.9
# 4  1/09/1949                                          4.0
#
#    Index Numbers ;  All groups CPI ;  Melbourne ;  \
# 0                                             3.8
# 1                                             3.8
# 2                                             3.9
# 3                                             4.0
# 4                                             4.1
#
#    Index Numbers ;  All groups CPI ;  Brisbane ;  \
# 0                                            3.7
# 1                                            3.7
# 2                                            3.8
# 3                                            3.9
# 4                                            4.0
#
#    Index Numbers ;  All groups CPI ;  Adelaide ;  \
# 0                                            3.8
# 1                                            3.9
# 2                                            4.0
# 3                                            4.0
# 4                                            4.1
#
#    Index Numbers ;  All groups CPI ;  Perth ;  \
# 0                                         3.7
# 1                                         3.8
# 2                                         3.9
# 3                                         4.0
# 4                                         4.1
#
#    Index Numbers ;  All groups CPI ;  Hobart ;  \
# 0                                          3.8
# 1                                          3.9
# 2                                          4.0
# 3                                          4.1
# 4                                          4.1
#
#    Index Numbers ;  All groups CPI ;  Darwin ;  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Index Numbers ;  All groups CPI ;  Canberra ;  \
# 0                                            3.9
# 1                                            4.1
# 2                                            4.1
# 3                                            4.2
# 4                                            4.3
#
#    Index Numbers ;  All groups CPI ;  Australia ;  ...  \
# 0                                             3.7  ...
# 1                                             3.8  ...
# 2                                             3.9  ...
# 3                                             4.0  ...
# 4                                             4.1  ...
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Australia ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               10.8
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Sydney ;  \
# 0                                                NaN
# 1                                                0.0
# 2                                                5.4
# 3                                                0.0
# 4                                                2.6
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Melbourne ;  \
# 0                                                NaN
# 1                                                0.0
# 2                                                2.6
# 3                                                2.6
# 4                                                2.5
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Brisbane ;  \
# 0                                                NaN
# 1                                                0.0
# 2                                                2.7
# 3                                                2.6
# 4                                                2.6
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Adelaide ;  \
# 0                                                NaN
# 1                                                2.6
# 2                                                2.6
# 3                                                0.0
# 4                                                2.5
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Perth ;  \
# 0                                                NaN
# 1                                                2.7
# 2                                                2.6
# 3                                                2.6
# 4                                                2.5
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Hobart ;  \
# 0                                                NaN
# 1                                                2.6
# 2                                                2.6
# 3                                                2.5
# 4                                                0.0
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Darwin ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Canberra ;  \
# 0                                                NaN
# 1                                                5.1
# 2                                                0.0
# 3                                                2.4
# 4                                                2.4
#
#    Percentage Change from Previous Period ;  All groups CPI ;  Australia ;
# 0                                                NaN
# 1                                                2.7
# 2                                                2.6
# 3                                                2.6
# 4                                                2.5
#
# [5 rows x 28 columns]

# %%
df1.isna().sum()
# Out:
# dates                                                                                               0
# Index Numbers ;  All groups CPI ;  Sydney ;                                                         0
# Index Numbers ;  All groups CPI ;  Melbourne ;                                                      0
# Index Numbers ;  All groups CPI ;  Brisbane ;                                                       0
# Index Numbers ;  All groups CPI ;  Adelaide ;                                                       0
# Index Numbers ;  All groups CPI ;  Perth ;                                                          0
# Index Numbers ;  All groups CPI ;  Hobart ;                                                         0
# Index Numbers ;  All groups CPI ;  Darwin ;                                                       128
# Index Numbers ;  All groups CPI ;  Canberra ;                                                       0
# Index Numbers ;  All groups CPI ;  Australia ;                                                      0
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Sydney ;         4
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Melbourne ;      4
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Brisbane ;       4
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Adelaide ;       4
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Perth ;          4
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Hobart ;         4
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Darwin ;       132
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Canberra ;       4
# Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Australia ;      4
# Percentage Change from Previous Period ;  All groups CPI ;  Sydney ;                                1
# Percentage Change from Previous Period ;  All groups CPI ;  Melbourne ;                             1
# Percentage Change from Previous Period ;  All groups CPI ;  Brisbane ;                              1
# Percentage Change from Previous Period ;  All groups CPI ;  Adelaide ;                              1
# Percentage Change from Previous Period ;  All groups CPI ;  Perth ;                                 1
# Percentage Change from Previous Period ;  All groups CPI ;  Hobart ;                                1
# Percentage Change from Previous Period ;  All groups CPI ;  Darwin ;                              129
# Percentage Change from Previous Period ;  All groups CPI ;  Canberra ;                              1
# Percentage Change from Previous Period ;  All groups CPI ;  Australia ;                             1
# dtype: int64

# %%
df_CPI = df1[["dates", "Index Numbers ;  All groups CPI ;  Sydney ;", "Index Numbers ;  All groups CPI ;  Melbourne ;", "Index Numbers ;  All groups CPI ;  Brisbane ;", "Index Numbers ;  All groups CPI ;  Adelaide ;", "Index Numbers ;  All groups CPI ;  Perth ;",	"Index Numbers ;  All groups CPI ;  Hobart ;", "Index Numbers ;  All groups CPI ;  Darwin ;", "Index Numbers ;  All groups CPI ;  Canberra ;",	"Index Numbers ;  All groups CPI ;  Australia ;"]]
df_CPI.head(10)
# Out:
#        dates  Index Numbers ;  All groups CPI ;  Sydney ;  \
# 0  1/09/1948                                          3.7
# 1  1/12/1948                                          3.7
# 2  1/03/1949                                          3.9
# 3  1/06/1949                                          3.9
# 4  1/09/1949                                          4.0
# 5  1/12/1949                                          4.1
# 6  1/03/1950                                          4.1
# 7  1/06/1950                                          4.3
# 8  1/09/1950                                          4.4
# 9  1/12/1950                                          4.6
#
#    Index Numbers ;  All groups CPI ;  Melbourne ;  \
# 0                                             3.8
# 1                                             3.8
# 2                                             3.9
# 3                                             4.0
# 4                                             4.1
# 5                                             4.2
# 6                                             4.3
# 7                                             4.4
# 8                                             4.5
# 9                                             4.6
#
#    Index Numbers ;  All groups CPI ;  Brisbane ;  \
# 0                                            3.7
# 1                                            3.7
# 2                                            3.8
# 3                                            3.9
# 4                                            4.0
# 5                                            4.1
# 6                                            4.1
# 7                                            4.2
# 8                                            4.3
# 9                                            4.4
#
#    Index Numbers ;  All groups CPI ;  Adelaide ;  \
# 0                                            3.8
# 1                                            3.9
# 2                                            4.0
# 3                                            4.0
# 4                                            4.1
# 5                                            4.1
# 6                                            4.2
# 7                                            4.4
# 8                                            4.4
# 9                                            4.6
#
#    Index Numbers ;  All groups CPI ;  Perth ;  \
# 0                                         3.7
# 1                                         3.8
# 2                                         3.9
# 3                                         4.0
# 4                                         4.1
# 5                                         4.2
# 6                                         4.2
# 7                                         4.4
# 8                                         4.5
# 9                                         4.6
#
#    Index Numbers ;  All groups CPI ;  Hobart ;  \
# 0                                          3.8
# 1                                          3.9
# 2                                          4.0
# 3                                          4.1
# 4                                          4.1
# 5                                          4.2
# 6                                          4.2
# 7                                          4.3
# 8                                          4.4
# 9                                          4.5
#
#    Index Numbers ;  All groups CPI ;  Darwin ;  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
#
#    Index Numbers ;  All groups CPI ;  Canberra ;  \
# 0                                            3.9
# 1                                            4.1
# 2                                            4.1
# 3                                            4.2
# 4                                            4.3
# 5                                            4.3
# 6                                            4.4
# 7                                            4.6
# 8                                            4.7
# 9                                            4.8
#
#    Index Numbers ;  All groups CPI ;  Australia ;
# 0                                             3.7
# 1                                             3.8
# 2                                             3.9
# 3                                             4.0
# 4                                             4.1
# 5                                             4.1
# 6                                             4.2
# 7                                             4.3
# 8                                             4.4
# 9                                             4.6

# %%
# Percentage change df per quarter 
percent_CPI_df = df1[["dates", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Sydney ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Melbourne ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Brisbane ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Adelaide ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Perth ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Hobart ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Darwin ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Canberra ;", "Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Australia ;"]]
percent_CPI_df.head()
# Out:
#        dates  \
# 0  1/09/1948
# 1  1/12/1948
# 2  1/03/1949
# 3  1/06/1949
# 4  1/09/1949
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Sydney ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                8.1
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Melbourne ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                7.9
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Brisbane ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                8.1
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Adelaide ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                7.9
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Perth ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               10.8
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Hobart ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                7.9
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Darwin ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Canberra ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               10.3
#
#    Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Australia ;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               10.8

# %%
# Multi line plot
ax = df_CPI.plot("dates", "Index Numbers ;  All groups CPI ;  Sydney ;", kind="line", label = 'Sydney')
df_CPI.plot("dates", "Index Numbers ;  All groups CPI ;  Melbourne ;", ax= ax , kind="line", label = 'Melbourne', title= 'MultiLine Plot') #ax : axes object
plt.figure(figsize=(22,15))
# Set axes
ax.set(ylabel='$ Dollars', xlabel = 'Year', xticks =df["dates"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1572         try:
# -> 1573             ret = self.converter.convert(x, self.units, self)
#    1574         except Exception as e:
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      49             raise ValueError(
# ---> 50                 'Missing category information for StrCategoryConverter; '
#      51                 'this might be caused by unintendedly mixing categorical and '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12504\874565629.py in <module>
#       4 plt.figure(figsize=(22,15))
#       5 # Set axes
# ----> 6 ax.set(ylabel='$ Dollars', xlabel = 'Year', xticks =df["dates"])
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1099             sorted(kwargs.items(), reverse=True,
#    1100                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1101         return self.update(props)
#    1102
#    1103     def findobj(self, match=None, include_self=True):
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#    1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
# -> 1003                 return func(v)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     398                 "parameter will become keyword-only %(removal)s.",
#     399                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 400         return func(*args, **kwargs)
#     401
#     402     return wrapper
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    3307             Default is ``False``.
#    3308         """
# -> 3309         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3310         self.stale = True
#    3311         return ret
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     398                 "parameter will become keyword-only %(removal)s.",
#     399                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 400         return func(*args, **kwargs)
#     401
#     402     return wrapper
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1759         """
#    1760         # XXX if the user changes units, the information will be lost here
# -> 1761         ticks = self.convert_units(ticks)
#    1762         if len(ticks) > 1:
#    1763             xleft, xright = self.get_view_interval()
#
# c:\Users\Conor\anaconda3\envs\PythonData\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1574         except Exception as e:
#    1575             raise munits.ConversionError('Failed to convert value(s) to axis '
# -> 1576                                          f'units: {x!r}') from e
#    1577         return ret
#    1578
#
# ConversionError: Failed to convert value(s) to axis units: 0      1/09/1997
# 1      1/12/1997
# 2      1/03/1998
# 3      1/06/1998
# 4      1/09/1998
#          ...
# 98     1/03/2022
# 99     1/06/2022
# 100    1/09/2022
# 101    1/12/2022
# 102    1/03/2023
# Name: dates, Length: 103, dtype: object

# %%
fig, ax = plt.subplots(figsize=[25,15])
ax = plt.plot(percent_CPI_df['dates'], percent_CPI_df['Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Australia ;'])
plt.grid(visible=True, which='both')
plt.xlabel('Date')
plt.ylabel('%')
plt.title('Australia percentage change in CPI')
plt.xticks(rotation=45)
plt.show()

print("It takes roughly 2 years for the sun to rotate around once, and takes roughly 730 days")
# Out:
# It takes roughly 2 years for the sun to rotate around once, and takes roughly 730 days

# %%
#new_percent_cpi = df1[df1['dates'] >= '1/12/1996']
#new_percent_cpi.head(10)

# %%
fig, ax = plt.subplots(figsize=[25,15])
ax = plt.plot(percent_CPI_df['dates'], percent_CPI_df['Percentage Change from Corresponding Quarter of Previous Year ;  All groups CPI ;  Australia ;'])
ax = plt.plot(percent_df["dates"], percent_df["Percentage Change from Previous Quarter Total hourly rates of pay excluding bonuses Australia Private and Public All industries "])
plt.grid(visible=True, which='both')
plt.xlabel('Date')
plt.ylabel('%')
plt.title('CPI VS WPI')
plt.xticks(rotation=45)
plt.show()

# %%
# Accumelated percent CPI
CPI_percent_increase = df1['Percentage Change from Previous Period ;  All groups CPI ;  Australia ;'].sum()
print(f"From 1/12/1948 There is an accumulated percentage increase in Consumer goods by: {CPI_percent_increase}%" )
CPI_price_increase = df1['Index Numbers ;  All groups CPI ;  Australia ;'].max() - df1['Index Numbers ;  All groups CPI ;  Australia ;'].min()
min = df1['Index Numbers ;  All groups CPI ;  Australia ;'].min()
max = df1['Index Numbers ;  All groups CPI ;  Australia ;'].max()
print(f"The difference in Public wage price increase is ${CPI_price_increase}")
print(f"The min is ${min}")
print(f"The max is ${max}")
# Out:
# From 1/12/1948 There is an accumulated percentage increase in Consumer goods by: 362.1%
# The difference in Public wage price increase is $128.9
# The min is $3.7
# The max is $132.6

# %%
# Accumelated percent CPI
CPI_percent_increase1 = df1['Percentage Change from Previous Period ;  All groups CPI ;  Australia ;'].sum()
print(f"From 1/12/1948 There is an accumulated percentage increase in Consumer goods by: {CPI_percent_increase1}%" )
CPI_price_increase = df1['Index Numbers ;  All groups CPI ;  Australia ;'].max() - df1['Index Numbers ;  All groups CPI ;  Australia ;'].min()
min = df1['Index Numbers ;  All groups CPI ;  Australia ;'].min()
max = df1['Index Numbers ;  All groups CPI ;  Australia ;'].max()
print(f"The difference in Public wage price increase is ${CPI_price_increase}")
print(f"The min is ${min}")
print(f"The max is ${max}")
# Out:
# From 1/12/1948 There is an accumulated percentage increase in Consumer goods by: 362.1%
# The difference in Public wage price increase is $128.9
# The min is $3.7
# The max is $132.6

# %%
df1['dates'] = pd.to_datetime(df1['dates'], dayfirst=True)

# %%
filtered_df1 = df1[df1['dates'] > '1997-01-01']

# %%
# Accumelated percent CPI
sum_value = filtered_df1['Percentage Change from Previous Period ;  All groups CPI ;  Australia ;'].sum()
print(f"From 1/12/1997 There is an accumulated percentage increase in Consumer goods by: {sum_value}%" )
CPI_price_increase_1 = filtered_df1['Index Numbers ;  All groups CPI ;  Australia ;'].max() - filtered_df1['Index Numbers ;  All groups CPI ;  Australia ;'].min()
min = filtered_df1['Index Numbers ;  All groups CPI ;  Australia ;'].min()
max = filtered_df1['Index Numbers ;  All groups CPI ;  Australia ;'].max()
print(f"The difference in Public wage price increase is ${CPI_price_increase_1}")
print(f"The min is ${min}")
print(f"The max is ${max}")
# Out:
# From 1/12/1997 There is an accumulated percentage increase in Consumer goods by: 68.6%
# The difference in Public wage price increase is $66.0
# The min is $66.6
# The max is $132.6
